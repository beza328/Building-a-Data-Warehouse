# %%
import pandas as pd
import sys
import os
import logging
from PIL import Image
sys.path.append(os.path.abspath('../scripts'))

# %%
import preprocessing as pr

# %%
import load_data as ld

# %%
# Set up logging for the notebook
logging.basicConfig(
    filename='notebook_data_cleaning.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %%
# Load CSV files
input_directory = 'C:/Users/BEZA/Desktop/week7/Building-a-Data-Warehouse/data'  # Specify your input directory
dfs = pr.load_csv_files(input_directory)
print(f"Loaded {len(dfs)} datasets.")
# Out:
# Loaded 5 datasets.

# %%
# Remove duplicates
dfs = pr.remove_duplicates(dfs)
print("Duplicates removed.")
# Out:
# Duplicates removed.

# %%
# Handle missing values
dfs = pr.handle_missing_values(dfs)
print("Missing values handled.")
# Out:
# Missing values handled.

# %%
dfs
# Out:
# [                                        Channel Title Channel Username    ID  \
#  0   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2424
#  1   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2423
#  2   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2422
#  3   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2421
#  4   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2420
#  5   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2419
#  6   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2417
#  7   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2416
#  8   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2414
#  9   ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2413
#  10  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2408
#  11  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2407
#  12  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2406
#  13  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2405
#  14  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2404
#  15  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2403
#  16  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2402
#  17  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2401
#  18  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2400
#  19  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...            EAHCI  2399
#
#                                                Message  \
#  0                                             ቸሽጧል!!!
#  1   #Dental_Extraction & #Care_Training \n        ...
#  2   #የግርዛት_ስልጠና_Addis Ababa\n#Circumcision_Skill_T...
#  3   #💥#ለሁሉም_ጤና_ባለሞያዎች_በሁሉም_ክልሎችና_ከተሞች ላላችሁ። ጥቅምት 1...
#  4   #Basic_Abdominal_Ultrasound_Training @Hawassa ...
#  5   #Hawassa_Obstetric_Ultrasound_Training\n👉ጥቅምት ...
#  6                                                 NaN
#  7   💥Adult_ECHO_Training_@#Bahirdar_By_Cardiologis...
#  8   💥ዛሬ ይጀምራል\nየሞያ_ፈቃድ_በቅርቡ_ለምታሳድሱ\n\n✔️#Title_Int...
#  9   #Hawassa_Obstetric_Ultrasound_Training\n👉ጥቅምት ...
#  10  #Monitoring_And_Evaluation_Training \n💥 Hawass...
#  11                                                NaN
#  12  #Ultrasound_For_Sale\n\n#New_with_used_Price \...
#  13  💥ነገ ይጀምራል\nየሞያ_ፈቃድ_በቅርቡ_ለምታሳድሱ\n\n✔️#Title_Int...
#  14                                                NaN
#  15                                                NaN
#  16  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
#  17  💥\nየሞያ_ፈቃድ_በቅርቡ_ለምታሳድሱ\n\n✔️#Title_Integrated_...
#  18  💥ለአዲስ_አበባ_ጤና_ባለሞያዎች \n\n#የሙያ_ ብቃት_ማረጋገጫ (licen...
#  19  💥 እሁድ ይጀምራል እንዳያመልጥዎ 💥\n#Obstetric_Ultrasound_...
#
#                           Date             Media Path
#  0   2024-10-18 11:12:54+00:00                    NaN
#  1   2024-10-18 09:17:43+00:00  photos\EAHCI_2423.jpg
#  2   2024-10-18 07:12:00+00:00  photos\EAHCI_2422.jpg
#  3   2024-10-17 15:52:57+00:00  photos\EAHCI_2421.jpg
#  4   2024-10-17 15:47:42+00:00  photos\EAHCI_2420.jpg
#  5   2024-10-17 13:26:11+00:00  photos\EAHCI_2419.jpg
#  6   2024-10-17 10:28:36+00:00                    NaN
#  7   2024-10-17 09:47:22+00:00  photos\EAHCI_2416.jpg
#  8   2024-10-16 10:41:27+00:00  photos\EAHCI_2414.jpg
#  9   2024-10-16 09:24:55+00:00  photos\EAHCI_2413.jpg
#  10  2024-10-15 20:11:16+00:00  photos\EAHCI_2408.jpg
#  11  2024-10-15 17:30:34+00:00  photos\EAHCI_2407.jpg
#  12  2024-10-15 17:30:34+00:00  photos\EAHCI_2406.jpg
#  13  2024-10-15 12:14:57+00:00  photos\EAHCI_2405.jpg
#  14  2024-10-13 14:03:08+00:00                    NaN
#  15  2024-10-13 13:42:46+00:00  photos\EAHCI_2403.jpg
#  16  2024-10-13 13:42:46+00:00  photos\EAHCI_2402.jpg
#  17  2024-10-13 13:39:28+00:00  photos\EAHCI_2401.jpg
#  18  2024-10-12 13:16:33+00:00                    NaN
#  19  2024-10-11 15:32:14+00:00  photos\EAHCI_2399.jpg  ,
#         Channel Title Channel Username   ID  \
#  0   Doctors Ethiopia       @DoctorsET  864
#  1   Doctors Ethiopia       @DoctorsET  863
#  2   Doctors Ethiopia       @DoctorsET  862
#  3   Doctors Ethiopia       @DoctorsET  861
#  4   Doctors Ethiopia       @DoctorsET  860
#  5   Doctors Ethiopia       @DoctorsET  859
#  6   Doctors Ethiopia       @DoctorsET  848
#  7   Doctors Ethiopia       @DoctorsET  847
#  8   Doctors Ethiopia       @DoctorsET  846
#  9   Doctors Ethiopia       @DoctorsET  845
#  10  Doctors Ethiopia       @DoctorsET  844
#  11  Doctors Ethiopia       @DoctorsET  843
#  12  Doctors Ethiopia       @DoctorsET  842
#  13  Doctors Ethiopia       @DoctorsET  841
#  14  Doctors Ethiopia       @DoctorsET  840
#  15  Doctors Ethiopia       @DoctorsET  839
#  16  Doctors Ethiopia       @DoctorsET  836
#  17  Doctors Ethiopia       @DoctorsET  835
#  18  Doctors Ethiopia       @DoctorsET  834
#  19  Doctors Ethiopia       @DoctorsET  833
#
#                                                Message  \
#  0   https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
#  1   ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
#  2   ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
#  3   ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
#  4   በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#  5   👇👇👇👇👇👇 https://youtu.be/-AR1KO2DbFw?si=47cXLZt...
#  6   ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...
#  7   ስፖርት የመስራት ሱስ ይኖር ይሆን?\n\nበአሁኑ ወቅት ብዙ የስፖርት መስ...
#  8   ድንገተኛ አደጋ / የአጥንት ስብራት\n\nአያርገውና ድንገተኛ የሆነ አደጋ...
#  9   ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላ...
#  10  ልጆች ላላችሁ / አባት እናት ወይንም እህት ወንድም / በቅርቡ ልጅ ለመው...
#  11  በብዙ ማህበራዊ ሚዲያዎች በ ከፋተኛ ሁኔታ እየተሸጠ ያለው \n\nፕሮቲን-...
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  
Lobelia pharmacy and cosmetics  lobelia4cosmetics  12562
#  19  Lobelia pharmacy and cosmetics  lobelia4cosmetics  12561
#
#                                                Message  \
#  0   Enfagrow A+\nPrice 5500 birr \nTelegram https:...
#  1   QUAKER OATS \nPrice 5000 birr \nTelegram https...
#  2   Cheerios \nPrice 2800\nTelegram https://t.me/l...
#  3   NIDO USA 2.2KG\nPrice 5900 birr \nTelegram htt...
#  4   HONEY BUNCHES \nPrice 2800\nTelegram https://t...
#  5   FERERO ROCHER 48 PIECES \nPrice 4500 birr \nTe...
#  6   go & grow 850gm\nPrice 5500 birr \nTelegram ht...
#  7   CARDIOACE PLUS\nPrice 5000 birr \nTelegram htt...
#  8   ENSURE 850GM\nPrice 3800 birr \nTelegram https...
#  9   SIMILAC ADVANCE \nPrice 3700 birr \nTelegram h...
#  10  GLUCERNA \nPrice 3300 birr \nTelegram https://...
#  11  ENFAMIL A PLUS 765GM \nPrice 5500 birr \nTeleg...
#  12  Aptamil No.3  800GM \nPrice 3600 birr \nTelegr...
#  13  Aptamil No.2  800GM \nPrice 3600 birr \nTelegr...
#  14  Aptamil No.1  800GM \nPrice 3600 birr \nTelegr...
#  15  ENSURE 850GM\nPrice 3800 birr \nTelegram https...
#  16  SIMILAC ADVANCE \nPrice 3700 birr \nTelegram h...
#  17  CENTRUM WOMEN 50+\nPrice 5700 birr \nTelegram ...
#  18  POSTNATAL 60 SOFTGELS \nPrice 6500 birr \nTele...
#  19  ONE A DAY WOMEN'S 300 TABLETS \nPrice 5500 bir...
#
#                           Date                          Media Path
#  0   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12580.jpg
#  1   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12579.jpg
#  2   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12578.jpg
#  3   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12577.jpg
#  4   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12576.jpg
#  5   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12575.jpg
#  6   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12574.jpg
#  7   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12573.jpg
#  8   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12572.jpg
#  9   2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12571.jpg
#  10  2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12570.jpg
#  11  2024-10-18 03:25:47+00:00  photos\lobelia4cosmetics_12569.jpg
#  12  2024-10-17 14:16:20+00:00  photos\lobelia4cosmetics_12568.jpg
#  13  2024-10-17 14:16:20+00:00  photos\lobelia4cosmetics_12567.jpg
#  14  2024-10-17 14:16:20+00:00  photos\lobelia4cosmetics_12566.jpg
#  15  2024-10-17 14:16:20+00:00  photos\lobelia4cosmetics_12565.jpg
#  16  2024-10-17 14:16:20+00:00  photos\lobelia4cosmetics_12564.jpg
#  17  2024-10-17 07:23:51+00:00  photos\lobelia4cosmetics_12563.jpg
#  18  2024-10-17 07:23:51+00:00  photos\lobelia4cosmetics_12562.jpg
#  19  2024-10-17 07:23:51+00:00  photos\lobelia4cosmetics_12561.jpg  ]

# %%
# Standardize formats
dfs = pr.standardize_formats(dfs)
print("Formats standardized.")
# Out:
# Formats standardized.
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# c:\Users\BEZA\Desktop\week7\Building-a-Data-Warehouse\scripts\preprocessing.py:52: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
# Validate data
pr.validate_data(dfs)

# %%
# Store cleaned data
output_directory = 'cleaned_data'
pr.store_cleaned_data(dfs, output_directory)
print("Cleaned data stored.")
# Out:
# Cleaned data stored.

# %%
# Process images
image_directory = 'C:/Users/BEZA/Desktop/week7/Building-a-Data-Warehouse/photos'  # Specify your input directory for images
processed_images_directory = 'processed_images'  # Specify your output directory for processed images
pr.process_images(image_directory, processed_images_directory)

# %%
# Load CSV files from the data directory
input_directory = 'C:/Users/BEZA/Desktop/week7/Building-a-Data-Warehouse/data'  # Directory containing your CSV files
dfs = ld.load_csv_files(input_directory)

# Create the database engine
engine = ld.get_engine()

# Store the cleaned data in the PostgreSQL database
ld.store_data_in_db(dfs, engine)
